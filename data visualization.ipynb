# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.ion()
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
n=19
file_path = '/data/home/acw694/CLIPort_new_loss/scratch/data_hdf5/bridge_crossview_goal.hdf5'

with h5py.File(file_path, 'r') as hdf:

    dataset_name_1 = 'image_s1'  # 替换为实际的名称
    dataset_name_2 = 'image_s2'
    lang_name = 'language'
    
    images_s1 = hdf[dataset_name_1][:100]
    images_s2 = hdf[dataset_name_2][:100]
    lang = hdf[lang_name][:100]
    
    img1 = images_s1[n]
    img2 = images_s2[n]
    l = lang[n]

    ax[0].imshow(img1)
    ax[1].imshow(img2)

    plt.draw()
    print(l)
# Out:
# b'end effector transition from object to object'
